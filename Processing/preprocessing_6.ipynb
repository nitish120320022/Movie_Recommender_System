# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
## Extracting features of 2022 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18732\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                     Title  \
# 0      J A N U A R Y        7.0                   The 355
# 1      J A N U A R Y        7.0  The Legend of La Llorona
# 2      J A N U A R Y        7.0              The Commando
# 3      J A N U A R Y        7.0            American Siege
# 4      J A N U A R Y       14.0                    Scream
# ..               ...        ...                       ...
# 324  D E C E M B E R       30.0            Alice, Darling
# 325  D E C E M B E R        NaN                       NaN
# 326  D E C E M B E R        NaN                       NaN
# 327  D E C E M B E R        NaN                       NaN
# 328  D E C E M B E R        NaN                       NaN
#
#                                     Production company  \
# 0    Universal Pictures / Freckle Films / FilmNatio...
# 1                       Saban Films / Ageless Pictures
# 2                 Saban Films / Premiere Entertainment
# 3                               Vertical Entertainment
# 4    Paramount Pictures / Spyglass Media Group / Ra...
# ..                                                 ...
# 324                     Lionsgate / Elevation Pictures
# 325                                                NaN
# 326                                                NaN
# 327                                                NaN
# 328                                                NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 324  Mary Nighy (director); Alanna Francis (screenp...
# 325                                                NaN
# 326                                                NaN
# 327                                                NaN
# 328                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 324                                                NaN
# 325                                                NaN
# 326                                                NaN
# 327                                                NaN
# 328                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 324  [261]
# 325    NaN
# 326    NaN
# 327    NaN
# 328    NaN
#
# [329 rows x 7 columns]

# %%
df_2022 = df[['Title','Cast and crew']]

# %%
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 324            Alice, Darling
# 325                       NaN
# 326                       NaN
# 327                       NaN
# 328                       NaN
#
#                                          Cast and crew
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 324  Mary Nighy (director); Alanna Francis (screenp...
# 325                                                NaN
# 326                                                NaN
# 327                                                NaN
# 328                                                NaN
#
# [329 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'ff3132c29c92e21e14539982f56e664a'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18732\2369738557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 324            Alice, Darling
# 325                       NaN
# 326                       NaN
# 327                       NaN
# 328                       NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 324  Mary Nighy (director); Alanna Francis (screenp...
# 325                                                NaN
# 326                                                NaN
# 327                                                NaN
# 328                                                NaN
#
#                               genres
# 0                    Action Thriller
# 1    Family Animation Fantasy Horror
# 2              Action Crime Thriller
# 3          Action Adventure Thriller
# 4            Horror Mystery Thriller
# ..                               ...
# 324           Thriller Mystery Drama
# 325                            Drama
# 326                            Drama
# 327                            Drama
# 328                            Drama
#
# [329 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18732\3796821595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18732\2929607607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18732\2384233428.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 324            Alice, Darling
# 325                       NaN
# 326                       NaN
# 327                       NaN
# 328                       NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 324  Mary Nighy (director); Alanna Francis (screenp...
# 325                                                NaN
# 326                                                NaN
# 327                                                NaN
# 328                                                NaN
#
#                               genres                         director_name  \
# 0                    Action Thriller                         Simon Kinberg
# 1    Family Animation Fantasy Horror                Patricia Harris Seeley
# 2              Action Crime Thriller                            Asif Akbar
# 3          Action Adventure Thriller                          Edward Drake
# 4            Horror Mystery Thriller  Matt Bettinelli-Olpin, Tyler Gillett
# ..                               ...                                   ...
# 324           Thriller Mystery Drama                            Mary Nighy
# 325                            Drama                                   nan
# 326                            Drama                                   nan
# 327                            Drama                                   nan
# 328                            Drama                                   nan
#
#           actor_1_name       actor_2_name     actor_3_name
# 0     Jessica Chastain     Lupita Nyong'o    Penélope Cruz
# 1        Autumn Reeser       Antonio Cupo      Danny Trejo
# 2        Mickey Rourke  Michael Jai White              NaN
# 3    Timothy V. Murphy       Bruce Willis              NaN
# 4      Melissa Barrera      Mason Gooding     Jenna Ortega
# ..                 ...                ...              ...
# 324      Anna Kendrick    Kaniehtiio Horn  Charlie Carrick
# 325                nan                NaN              NaN
# 326                nan                NaN              NaN
# 327                nan                NaN              NaN
# 328                nan                NaN              NaN
#
# [329 rows x 7 columns]

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df22
# Out:
#                             director_name       actor_1_name  \
# 0                           Simon Kinberg   Jessica Chastain
# 1                  Patricia Harris Seeley      Autumn Reeser
# 2                              Asif Akbar      Mickey Rourke
# 3                            Edward Drake  Timothy V. Murphy
# 4    Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera
# ..                                    ...                ...
# 324                            Mary Nighy      Anna Kendrick
# 325                                   nan                nan
# 326                                   nan                nan
# 327                                   nan                nan
# 328                                   nan                nan
#
#           actor_2_name     actor_3_name                           genres  \
# 0       Lupita Nyong'o    Penélope Cruz                  Action Thriller
# 1         Antonio Cupo      Danny Trejo  Family Animation Fantasy Horror
# 2    Michael Jai White              NaN            Action Crime Thriller
# 3         Bruce Willis              NaN        Action Adventure Thriller
# 4        Mason Gooding     Jenna Ortega          Horror Mystery Thriller
# ..                 ...              ...                              ...
# 324    Kaniehtiio Horn  Charlie Carrick           Thriller Mystery Drama
# 325                NaN              NaN                            Drama
# 326                NaN              NaN                            Drama
# 327                NaN              NaN                            Drama
# 328                NaN              NaN                            Drama
#
#                   movie_title
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 324            Alice, Darling
# 325                       NaN
# 326                       NaN
# 327                       NaN
# 328                       NaN
#
# [329 rows x 6 columns]

# %%
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df22['actor_2_name'] + ' '+ new_df22['actor_3_name'] + ' '+ new_df22['director_name'] +' ' + new_df22['genres']

# %%
new_df22.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      9
# actor_3_name     35
# genres            1
# movie_title       4
# comb             36
# dtype: int64

# %%
new_df22 = new_df22.dropna(how='any')

# %%
new_df22.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18732\2732328091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22
# Out:
#                             director_name      actor_1_name     actor_2_name  \
# 0                           Simon Kinberg  Jessica Chastain   Lupita Nyong'o
# 1                  Patricia Harris Seeley     Autumn Reeser     Antonio Cupo
# 4    Matt Bettinelli-Olpin, Tyler Gillett   Melissa Barrera    Mason Gooding
# 5           Jennifer Kluska, Derek Drymon      Andy Samberg     Selena Gomez
# 6                             Luis Prieto  Cameron Monaghan     Frank Grillo
# ..                                    ...               ...              ...
# 320                          Kasi Lemmons       Naomi Ackie    Stanley Tucci
# 321                          Scott Cooper    Christian Bale    Harry Melling
# 322                          Sarah Polley       Rooney Mara       Claire Foy
# 323                          Marc Forster         Tom Hanks  Mariana Treviño
# 324                            Mary Nighy     Anna Kendrick  Kaniehtiio Horn
#
#          actor_3_name                                     genres  \
# 0       Penélope Cruz                            Action Thriller
# 1         Danny Trejo            Family Animation Fantasy Horror
# 4        Jenna Ortega                    Horror Mystery Thriller
# 5        Kathryn Hahn  Animation Comedy Family Fantasy Adventure
# 6          Lilly Krug                                   Thriller
# ..                ...                                        ...
# 320    Ashton Sanders                        Music History Drama
# 321  Gillian Anderson                                      Crime
# 322    Jessie Buckley                                      Drama
# 323     Rachel Keller                               Comedy Drama
# 324   Charlie Carrick                     Thriller Mystery Drama
#
#                                       movie_title  \
# 0                                         the 355
# 1                        the legend of la llorona
# 4                                          scream
# 5               hotel transylvania: transformania
# 6                                       shattered
# ..                                            ...
# 320  whitney houston: i wanna dance with somebody
# 321                             the pale blue eye
# 322                                 women talking
# 323                             a man called otto
# 324                                alice, darling
#
#                                                   comb
# 0    Jessica Chastain Lupita Nyong'o Penélope Cruz ...
# 1    Autumn Reeser Antonio Cupo Danny Trejo Patrici...
# 4    Melissa Barrera Mason Gooding Jenna Ortega Mat...
# 5    Andy Samberg Selena Gomez Kathryn Hahn Jennife...
# 6    Cameron Monaghan Frank Grillo Lilly Krug Luis ...
# ..                                                 ...
# 320  Naomi Ackie Stanley Tucci Ashton Sanders Kasi ...
# 321  Christian Bale Harry Melling Gillian Anderson ...
# 322  Rooney Mara Claire Foy Jessie Buckley Sarah Po...
# 323  Tom Hanks Mariana Treviño Rachel Keller Marc F...
# 324  Anna Kendrick Kaniehtiio Horn Charlie Carrick ...
#
# [293 rows x 7 columns]

# %%
old_df = pd.read_csv('datasets/final_data.csv')

# %%
old_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5879  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5880            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5881              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5882   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5883         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5879         Rashida Jones  Animation Action Adventure Comedy Family
# 5880         Florence Pugh                     Drama Romance History
# 5881           Mark Strong                         War Drama History
# 5882           Brie Larson                       Drama Crime History
# 5883           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5879                                  spies in disguise
# 5880                                       little women
# 5881                                               1917
# 5882                                         just mercy
# 5883                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5879  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5880  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5881  George MacKay Dean-Charles Chapman Mark Strong...
# 5882  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5883  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5884 rows x 7 columns]

# %%
final_df = old_df.append(new_df22,ignore_index=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18732\1166909226.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(new_df22,ignore_index=True)

# %%
final_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6172       Kasi Lemmons      Naomi Ackie     Stanley Tucci
# 6173       Scott Cooper   Christian Bale     Harry Melling
# 6174       Sarah Polley      Rooney Mara        Claire Foy
# 6175       Marc Forster        Tom Hanks   Mariana Treviño
# 6176         Mary Nighy    Anna Kendrick   Kaniehtiio Horn
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6172        Ashton Sanders              Music History Drama
# 6173      Gillian Anderson                            Crime
# 6174        Jessie Buckley                            Drama
# 6175         Rachel Keller                     Comedy Drama
# 6176       Charlie Carrick           Thriller Mystery Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6172       whitney houston: i wanna dance with somebody
# 6173                                  the pale blue eye
# 6174                                      women talking
# 6175                                  a man called otto
# 6176                                     alice, darling
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6172  Naomi Ackie Stanley Tucci Ashton Sanders Kasi ...
# 6173  Christian Bale Harry Melling Gillian Anderson ...
# 6174  Rooney Mara Claire Foy Jessie Buckley Sarah Po...
# 6175  Tom Hanks Mariana Treviño Rachel Keller Marc F...
# 6176  Anna Kendrick Kaniehtiio Horn Charlie Carrick ...
#
# [6177 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
