# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
## Extracting features of 2021 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11704\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                   Title  \
# 0      J A N U A R Y        1.0     Shadow in the Cloud
# 1      J A N U A R Y       13.0         The White Tiger
# 2      J A N U A R Y       14.0             Locked Down
# 3      J A N U A R Y       15.0                 The Dig
# 4      J A N U A R Y       15.0        Outside the Wire
# ..               ...        ...                     ...
# 356  D E C E M B E R       25.0  The Tragedy of Macbeth
# 357  D E C E M B E R       25.0    A Journal for Jordan
# 358  D E C E M B E R       25.0       American Underdog
# 359  D E C E M B E R       26.0                 Memoria
# 360  D E C E M B E R        NaN                     NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                                Netflix / Noruz Films
# 2                      HBO Max / Warner Bros. Pictures
# 3                          Netflix / Clerkenwell Films
# 4                                              Netflix
# ..                                                 ...
# 356                        Apple TV+ / A24 / IAC Films
# 357  Columbia Pictures / Escape Artists / Bron Studios
# 358                                          Lionsgate
# 359                                               Neon
# 360                                                NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 356  Joel Coen (director/screenplay); Denzel Washin...
# 357  Denzel Washington (director); Virgil Williams ...
# 358  Erwin brothers (directors); Jon Erwin, David A...
# 359  Apichatpong Weerasethakul (director/acreenplay...
# 360                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  NaN
# 2                                                  [3]
# 3                                                  [4]
# 4                                                  [5]
# ..                                                 ...
# 356                                                NaN
# 357                                                NaN
# 358                                                NaN
# 359                                                NaN
# 360                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 356  [273]
# 357  [274]
# 358  [275]
# 359  [276]
# 360    NaN
#
# [361 rows x 7 columns]

# %%
df_2021 = df[['Title','Cast and crew']]

# %%
df_2021
# Out:
#                       Title                                      Cast and crew
# 0       Shadow in the Cloud  Roseanne Liang (director/screenplay); Max Land...
# 1           The White Tiger  Ramin Bahrani (director/screenplay); Adarsh Go...
# 2               Locked Down  Doug Liman (director); Steven Knight (screenpl...
# 3                   The Dig  Simon Stone (director); Moira Buffini (screenp...
# 4          Outside the Wire  Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                      ...                                                ...
# 356  The Tragedy of Macbeth  Joel Coen (director/screenplay); Denzel Washin...
# 357    A Journal for Jordan  Denzel Washington (director); Virgil Williams ...
# 358       American Underdog  Erwin brothers (directors); Jon Erwin, David A...
# 359                 Memoria  Apichatpong Weerasethakul (director/acreenplay...
# 360                     NaN                                                NaN
#
# [361 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'ff3132c29c92e21e14539982f56e664a'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11704\3587185986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2021
# Out:
#                       Title  \
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 356  The Tragedy of Macbeth
# 357    A Journal for Jordan
# 358       American Underdog
# 359                 Memoria
# 360                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 356  Joel Coen (director/screenplay); Denzel Washin...
# 357  Denzel Washington (director); Virgil Williams ...
# 358  Erwin brothers (directors); Jon Erwin, David A...
# 359  Apichatpong Weerasethakul (director/acreenplay...
# 360                                                NaN
#
#                               genres
# 0                  Horror Action War
# 1                              Drama
# 2                 Comedy Crime Drama
# 3                      Drama History
# 4    Thriller Action Science Fiction
# ..                               ...
# 356                        Drama War
# 357                    Drama Romance
# 358                            Drama
# 359                            Drama
# 360                            Drama
#
# [361 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11704\3118254134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11704\1611661901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11704\3001516348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2021
# Out:
#                       Title  \
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 356  The Tragedy of Macbeth
# 357    A Journal for Jordan
# 358       American Underdog
# 359                 Memoria
# 360                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 356  Joel Coen (director/screenplay); Denzel Washin...
# 357  Denzel Washington (director); Virgil Williams ...
# 358  Erwin brothers (directors); Jon Erwin, David A...
# 359  Apichatpong Weerasethakul (director/acreenplay...
# 360                                                NaN
#
#                               genres  \
# 0                  Horror Action War
# 1                              Drama
# 2                 Comedy Crime Drama
# 3                      Drama History
# 4    Thriller Action Science Fiction
# ..                               ...
# 356                        Drama War
# 357                    Drama Romance
# 358                            Drama
# 359                            Drama
# 360                            Drama
#
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 356                                          Joel Coen
# 357                                  Denzel Washington
# 358                                     Erwin brothers
# 359  Apichatpong Weerasethakul (director/acreenplay...
# 360                                                nan
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# 3                                       Carey Mulligan      Ralph Fiennes
# 4                                       Anthony Mackie       Damson Idris
# ..                                                 ...                ...
# 356                                  Denzel Washington  Frances McDormand
# 357                                  Michael B. Jordan       Chanté Adams
# 358                                       Zachary Levi        Anna Paquin
# 359  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
# 360                                                nan                NaN
#
#               actor_3_name
# 0             Beulah Koale
# 1    Priyanka Chopra Jonas
# 2         Stephen Merchant
# 3               Lily James
# 4            Emily Beecham
# ..                     ...
# 356          Bertie Carvel
# 357        Jalon Christian
# 358           Dennis Quaid
# 359         Jeanne Balibar
# 360                    NaN
#
# [361 rows x 7 columns]

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 356                                          Joel Coen
# 357                                  Denzel Washington
# 358                                     Erwin brothers
# 359  Apichatpong Weerasethakul (director/acreenplay...
# 360                                                nan
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# 3                                       Carey Mulligan      Ralph Fiennes
# 4                                       Anthony Mackie       Damson Idris
# ..                                                 ...                ...
# 356                                  Denzel Washington  Frances McDormand
# 357                                  Michael B. Jordan       Chanté Adams
# 358                                       Zachary Levi        Anna Paquin
# 359  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
# 360                                                nan                NaN
#
#               actor_3_name                           genres  \
# 0             Beulah Koale                Horror Action War
# 1    Priyanka Chopra Jonas                            Drama
# 2         Stephen Merchant               Comedy Crime Drama
# 3               Lily James                    Drama History
# 4            Emily Beecham  Thriller Action Science Fiction
# ..                     ...                              ...
# 356          Bertie Carvel                        Drama War
# 357        Jalon Christian                    Drama Romance
# 358           Dennis Quaid                            Drama
# 359         Jeanne Balibar                            Drama
# 360                    NaN                            Drama
#
#                 movie_title
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 356  The Tragedy of Macbeth
# 357    A Journal for Jordan
# 358       American Underdog
# 359                 Memoria
# 360                     NaN
#
# [361 rows x 6 columns]

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']

# %%
new_df21.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      8
# actor_3_name     26
# genres            1
# movie_title       1
# comb             27
# dtype: int64

# %%
new_df21 = new_df21.dropna(how='any')

# %%
new_df21.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df21['movie_title'] = new_df21['movie_title'].str.lower()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11704\2732271610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df21['movie_title'] = new_df21['movie_title'].str.lower()

# %%
new_df21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 355                                     Matthew Vaughn
# 356                                          Joel Coen
# 357                                  Denzel Washington
# 358                                     Erwin brothers
# 359  Apichatpong Weerasethakul (director/acreenplay...
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# 3                                       Carey Mulligan      Ralph Fiennes
# 4                                       Anthony Mackie       Damson Idris
# ..                                                 ...                ...
# 355                                      Ralph Fiennes     Gemma Arterton
# 356                                  Denzel Washington  Frances McDormand
# 357                                  Michael B. Jordan       Chanté Adams
# 358                                       Zachary Levi        Anna Paquin
# 359  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#               actor_3_name                                 genres  \
# 0             Beulah Koale                      Horror Action War
# 1    Priyanka Chopra Jonas                                  Drama
# 2         Stephen Merchant                     Comedy Crime Drama
# 3               Lily James                          Drama History
# 4            Emily Beecham        Thriller Action Science Fiction
# ..                     ...                                    ...
# 355             Rhys Ifans  Action Adventure Thriller War Mystery
# 356          Bertie Carvel                              Drama War
# 357        Jalon Christian                          Drama Romance
# 358           Dennis Quaid                                  Drama
# 359         Jeanne Balibar                                  Drama
#
#                 movie_title                                               comb
# 0       shadow in the cloud  Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1           the white tiger  Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 2               locked down  Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# 3                   the dig  Carey Mulligan Ralph Fiennes Lily James Simon ...
# 4          outside the wire  Anthony Mackie Damson Idris Emily Beecham Mika...
# ..                      ...                                                ...
# 355          the king's man  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 356  the tragedy of macbeth  Denzel Washington Frances McDormand Bertie Car...
# 357    a journal for jordan  Michael B. Jordan Chanté Adams Jalon Christian...
# 358       american underdog  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 359                 memoria  Apichatpong Weerasethakul (director/acreenplay...
#
# [334 rows x 7 columns]

# %%
old_df = pd.read_csv('datasets/final_data.csv')

# %%
old_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5879  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5880            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5881              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5882   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5883         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5879         Rashida Jones  Animation Action Adventure Comedy Family
# 5880         Florence Pugh                     Drama Romance History
# 5881           Mark Strong                         War Drama History
# 5882           Brie Larson                       Drama Crime History
# 5883           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5879                                  spies in disguise
# 5880                                       little women
# 5881                                               1917
# 5882                                         just mercy
# 5883                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5879  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5880  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5881  George MacKay Dean-Charles Chapman Mark Strong...
# 5882  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5883  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5884 rows x 7 columns]

# %%
final_df = old_df.append(new_df21,ignore_index=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11704\545207046.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(new_df21,ignore_index=True)

# %%
final_df
# Out:
#                                           director_name  \
# 0                                         James Cameron
# 1                                        Gore Verbinski
# 2                                            Sam Mendes
# 3                                     Christopher Nolan
# 4                                           Doug Walker
# ...                                                 ...
# 6213                                     Matthew Vaughn
# 6214                                          Joel Coen
# 6215                                  Denzel Washington
# 6216                                     Erwin brothers
# 6217  Apichatpong Weerasethakul (director/acreenplay...
#
#                                            actor_1_name       actor_2_name  \
# 0                                           CCH Pounder   Joel David Moore
# 1                                           Johnny Depp      Orlando Bloom
# 2                                       Christoph Waltz       Rory Kinnear
# 3                                             Tom Hardy     Christian Bale
# 4                                           Doug Walker         Rob Walker
# ...                                                 ...                ...
# 6213                                      Ralph Fiennes     Gemma Arterton
# 6214                                  Denzel Washington  Frances McDormand
# 6215                                  Michael B. Jordan       Chanté Adams
# 6216                                       Zachary Levi        Anna Paquin
# 6217  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#               actor_3_name                                 genres  \
# 0                Wes Studi        Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport               Action Adventure Fantasy
# 2         Stephanie Sigman              Action Adventure Thriller
# 3     Joseph Gordon-Levitt                        Action Thriller
# 4                  unknown                            Documentary
# ...                    ...                                    ...
# 6213            Rhys Ifans  Action Adventure Thriller War Mystery
# 6214         Bertie Carvel                              Drama War
# 6215       Jalon Christian                          Drama Romance
# 6216          Dennis Quaid                                  Drama
# 6217        Jeanne Balibar                                  Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6213                                     the king's man
# 6214                             the tragedy of macbeth
# 6215                               a journal for jordan
# 6216                                  american underdog
# 6217                                            memoria
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6213  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 6214  Denzel Washington Frances McDormand Bertie Car...
# 6215  Michael B. Jordan Chanté Adams Jalon Christian...
# 6216  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 6217  Apichatpong Weerasethakul (director/acreenplay...
#
# [6218 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
